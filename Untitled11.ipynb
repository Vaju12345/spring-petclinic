# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaju12345/spring-petclinic/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-37bec95d-3f56-4431-84fc-f133efbc7b95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37bec95d-3f56-4431-84fc-f133efbc7b95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv(list(uploaded.keys())[0])

# %%
df.head()
# Out:
#   show_id     type          title      director              cast country  \
# 0      s1    Movie        Red Sky    John Smith  Actor A; Actor B     USA
# 1      s2  TV Show   Dark Secrets      Anna Lee  Actor C; Actor D      UK
# 2      s3    Movie     Love Again   Emily Clark  Actor E; Actor F  Canada
# 3      s4  TV Show    Crime Files  David Miller  Actor G; Actor H     USA
# 4      s5    Movie  The Last Hero   Chris Nolan  Actor I; Actor J     USA
#
#          date_added  release_year rating   duration listed_in  \
# 0    January 1 2020          2019  PG-13     90 min    Action
# 1     March 15 2021          2021  TV-MA  2 Seasons     Drama
# 2  February 10 2019          2018     PG    105 min   Romance
# 3      July 22 2020          2020  TV-14  3 Seasons     Crime
# 4        May 5 2018          2017      R    120 min    Action
#
#                                  description
# 0  A pilot fights against odds to save lives
# 1             A thriller about hidden truths
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       20 non-null     object
#  1   type          20 non-null     object
#  2   title         20 non-null     object
#  3   director      20 non-null     object
#  4   cast          20 non-null     object
#  5   country       20 non-null     object
#  6   date_added    20 non-null     object
#  7   release_year  20 non-null     int64
#  8   rating        20 non-null     object
#  9   duration      20 non-null     object
#  10  listed_in     20 non-null     object
#  11  description   20 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 2.0+ KB

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.describe()
# Out:
#        release_year
# count     20.000000
# mean    2019.500000
# std        1.638356
# min     2016.000000
# 25%     2018.750000
# 50%     2020.000000
# 75%     2021.000000
# max     2022.000000

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df["director"].fillna("unknow",inplace=True)
df["cast"].fillna("unknow",inplace=True)
df["country"].fillna("unknow",inplace=True)
# Out:
# /tmp/ipykernel_4700/2488418135.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["director"].fillna("unknow",inplace=True)
# /tmp/ipykernel_4700/2488418135.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df["date_added"]=pd.to_datetime(df["date_added"])
df
# Out:
#    show_id     type          title          director                cast  \
# 0       s1    Movie        Red Sky        John Smith    Actor A; Actor B
# 1       s2  TV Show   Dark Secrets          Anna Lee    Actor C; Actor D
# 2       s3    Movie     Love Again       Emily Clark    Actor E; Actor F
# 3       s4  TV Show    Crime Files      David Miller    Actor G; Actor H
# 4       s5    Movie  The Last Hero       Chris Nolan    Actor I; Actor J
# 5       s6  TV Show  Comedy Nights          Jane Doe    Actor K; Actor L
# 6       s7    Movie     Ocean Deep         Mark Blue    Actor M; Actor N
# 7       s8    Movie  Haunted House        Sarah King    Actor O; Actor P
# 8       s9  TV Show     Tech World       Alan Turing    Actor Q; Actor R
# 9      s10    Movie      Fast Lane         Raj Kumar    Actor S; Actor T
# 10     s11    Movie   Silent Night       Maria Lopez    Actor U; Actor V
# 11     s12  TV Show    History 101         Tom Hardy    Actor W; Actor X
# ...

# %%
df["year_added"]=df["date_added"].dt.year
df["month_added"]=df["date_added"].dt.month
df
# Out:
#    show_id     type          title          director                cast  \
# 0       s1    Movie        Red Sky        John Smith    Actor A; Actor B
# 1       s2  TV Show   Dark Secrets          Anna Lee    Actor C; Actor D
# 2       s3    Movie     Love Again       Emily Clark    Actor E; Actor F
# 3       s4  TV Show    Crime Files      David Miller    Actor G; Actor H
# 4       s5    Movie  The Last Hero       Chris Nolan    Actor I; Actor J
# 5       s6  TV Show  Comedy Nights          Jane Doe    Actor K; Actor L
# 6       s7    Movie     Ocean Deep         Mark Blue    Actor M; Actor N
# 7       s8    Movie  Haunted House        Sarah King    Actor O; Actor P
# 8       s9  TV Show     Tech World       Alan Turing    Actor Q; Actor R
# 9      s10    Movie      Fast Lane         Raj Kumar    Actor S; Actor T
# 10     s11    Movie   Silent Night       Maria Lopez    Actor U; Actor V
# 11     s12  TV Show    History 101         Tom Hardy    Actor W; Actor X
# ...

# %%
df["duration"]=df["duration"].str.replace(' min'," ")
df["duration"]=df["duration"].str.replace(' Seasons', '')
df["duration"]=pd.to_numeric(df["duration"],errors="coerce")
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4700/2246592822.py in <cell line: 0>()
# ----> 1 df["duration"]=df["duration"].str.replace(' min'," ")
#       2 df["duration"]=df["duration"].str.replace(' Seasons', '')
#       3 df["duration"]=pd.to_numeric(df["duration"],errors="coerce")
#       4 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='type', data=df)

plt.title("Movies vs TV Shows")
plt.show()

# %%
df['year_added'].value_counts()
# Out:
# year_added
# 2021    6
# 2020    5
# 2019    4
# 2018    2
# 2022    1
# 2017    1
# 2016    1
# Name: count, dtype: int64

# %%
df['year_added'].value_counts().sort_index().plot(kind='line')
plt.title("Content Added Over Years")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
top_countries = df['country'].value_counts().head(10)
top_countries.plot(kind='bar')
plt.title("Top 10 Countries Producing Content")
plt.show()

# %%
genres = df['listed_in'].str.split(',', expand=True).stack()
genres.value_counts().head(10).plot(kind='bar')
plt.title("Top Genres on Netflix")
plt.show()

# %%
df['rating'].value_counts().plot(kind='bar')
plt.title("Ratings Distribution")
plt.show()

# %%
movies = df[df['type'] == 'Movie']

sns.histplot(movies['duration'], bins=30)
plt.title("Movie Duration Distribution")
plt.show()

# %%
tv_shows = df[df['type'] == 'TV Show']

sns.histplot(tv_shows['duration'], bins=10)
plt.title("TV Show Seasons Distribution")
plt.show()

# %%
df.groupby('year_added')['type'].count().plot()
plt.title("Netflix Growth Over Time")
plt.show()

# %%
pd.crosstab(df['country'], df['type']).head(10)
# Out:
# type       Movie  TV Show
# country
# Australia      1        1
# Canada         1        0
# India          2        1
# Spain          1        0
# UK             1        2
# USA            6        4

# %%
df['director'].value_counts().head(10).plot(kind='bar')
plt.title("Top Directors")
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-87956a97-981e-4baa-8063-52d26535e540" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87956a97-981e-4baa-8063-52d26535e540">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
#   Order_ID  Order_Date Region  Product     Category    Sales  Profit  \
# 0  ORD0001  2023-11-24  South    Phone  Electronics  1496.02  166.39
# 1  ORD0002  2023-02-22  South    Phone  Electronics   872.75   50.14
# 2  ORD0003  2023-09-16   West   Laptop  Electronics   437.73   93.00
# 3  ORD0004  2023-08-18   West  Monitor  Electronics  1529.67  137.54
# 4  ORD0005  2023-05-23  North   Tablet  Electronics  1916.57  257.11
#
#    Quantity     Customer
# 0         1  Customer_95
# 1        10  Customer_30
# 2         9  Customer_29
# 3         1  Customer_44
# 4         4  Customer_49

# %%
df.head(6)
# Out:
#   Order_ID  Order_Date Region   Product     Category    Sales  Profit  \
# 0  ORD0001  2023-11-24  South     Phone  Electronics  1496.02  166.39
# 1  ORD0002  2023-02-22  South     Phone  Electronics   872.75   50.14
# 2  ORD0003  2023-09-16   West    Laptop  Electronics   437.73   93.00
# 3  ORD0004  2023-08-18   West   Monitor  Electronics  1529.67  137.54
# 4  ORD0005  2023-05-23  North    Tablet  Electronics  1916.57  257.11
# 5  ORD0006  2023-02-19   West  Keyboard  Accessories  1227.27  309.00
#
#    Quantity     Customer
# 0         1  Customer_95
# 1        10  Customer_30
# 2         9  Customer_29
# 3         1  Customer_44
# 4         4  Customer_49
# 5         6  Customer_69

# %%
df.shape
# Out:
# (500, 9)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Region', 'Product', 'Category', 'Sales',
#        'Profit', 'Quantity', 'Customer'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order_ID       object
# Order_Date     object
# Region         object
# Product        object
# Category       object
# Sales         float64
# Profit        float64
# Quantity        int64
# Customer       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID      0
# Order_Date    0
# Region        0
# Product       0
# Category      0
# Sales         0
# Profit        0
# Quantity      0
# Customer      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull()
# Out:
#      Order_ID  Order_Date  Region  Product  Category  Sales  Profit  Quantity  \
# 0       False       False   False    False     False  False   False     False
# 1       False       False   False    False     False  False   False     False
# 2       False       False   False    False     False  False   False     False
# 3       False       False   False    False     False  False   False     False
# 4       False       False   False    False     False  False   False     False
# ..        ...         ...     ...      ...       ...    ...     ...       ...
# 495     False       False   False    False     False  False   False     False
# 496     False       False   False    False     False  False   False     False
# 497     False       False   False    False     False  False   False     False
# 498     False       False   False    False     False  False   False     False
# 499     False       False   False    False     False  False   False     False
#
#      Customer
# 0       False
# ...

# %%
df["Profit"]=df["Profit"].fillna(df["Profit"].mean)
df
# Out:
#     Order_ID  Order_Date Region   Product     Category    Sales  Profit  \
# 0    ORD0001  2023-11-24  South     Phone  Electronics  1496.02  166.39
# 1    ORD0002  2023-02-22  South     Phone  Electronics   872.75   50.14
# 2    ORD0003  2023-09-16   West    Laptop  Electronics   437.73   93.00
# 3    ORD0004  2023-08-18   West   Monitor  Electronics  1529.67  137.54
# 4    ORD0005  2023-05-23  North    Tablet  Electronics  1916.57  257.11
# ..       ...         ...    ...       ...          ...      ...     ...
# 495  ORD0496  2023-05-25   West   Monitor  Electronics   237.04   35.14
# 496  ORD0497  2023-01-28   West  Keyboard  Accessories   883.83  109.27
# 497  ORD0498  2023-02-19  North    Laptop  Electronics   383.12   47.11
# 498  ORD0499  2023-03-01   East   Monitor  Electronics   968.34  265.05
# 499  ORD0500  2023-11-25  South     Mouse  Accessories   773.49  112.44
#
#      Quantity     Customer
# 0           1  Customer_95
# 1          10  Customer_30
# ...

# %%
df["Order_Date"]=pd.to_datetime(df["Order_Date"])
df
# Out:
#     Order_ID Order_Date Region   Product     Category    Sales  Profit  \
# 0    ORD0001 2023-11-24  South     Phone  Electronics  1496.02  166.39
# 1    ORD0002 2023-02-22  South     Phone  Electronics   872.75   50.14
# 2    ORD0003 2023-09-16   West    Laptop  Electronics   437.73   93.00
# 3    ORD0004 2023-08-18   West   Monitor  Electronics  1529.67  137.54
# 4    ORD0005 2023-05-23  North    Tablet  Electronics  1916.57  257.11
# ..       ...        ...    ...       ...          ...      ...     ...
# 495  ORD0496 2023-05-25   West   Monitor  Electronics   237.04   35.14
# 496  ORD0497 2023-01-28   West  Keyboard  Accessories   883.83  109.27
# 497  ORD0498 2023-02-19  North    Laptop  Electronics   383.12   47.11
# 498  ORD0499 2023-03-01   East   Monitor  Electronics   968.34  265.05
# 499  ORD0500 2023-11-25  South     Mouse  Accessories   773.49  112.44
#
#      Quantity     Customer
# 0           1  Customer_95
# 1          10  Customer_30
# 2           9  Customer_29
# ...

# %%
df["Region"]=df["Region"].astype(str).strip().str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1467/120905349.py in <cell line: 0>()
# ----> 1 df["Region"]=df["Region"].astype(str).strip().str.lower()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
df["Region"] = df["Region"].astype(str).str.strip().str.lower()

# %%
df["Region"]=df["Region"].astype(str).str.strip()
df["Product"]=df["Product"].astype(str).str.strip()
df["Category"]=df["Category"].astype(str).str.strip()

# %%
df["Region"]=df["Region"].astype(str).str.strip().str.title()
df["Product"]=df["Product"].astype(str).str.strip().str.upper()
df["Category"]=df["Category"].astype(str).str.strip().str.lower()
df
# Out:
#     Order_ID Order_Date Region   Product     Category    Sales  Profit  \
# 0    ORD0001 2023-11-24  South     PHONE  electronics  1496.02  166.39
# 1    ORD0002 2023-02-22  South     PHONE  electronics   872.75   50.14
# 2    ORD0003 2023-09-16   West    LAPTOP  electronics   437.73   93.00
# 3    ORD0004 2023-08-18   West   MONITOR  electronics  1529.67  137.54
# 4    ORD0005 2023-05-23  North    TABLET  electronics  1916.57  257.11
# ..       ...        ...    ...       ...          ...      ...     ...
# 495  ORD0496 2023-05-25   West   MONITOR  electronics   237.04   35.14
# 496  ORD0497 2023-01-28   West  KEYBOARD  accessories   883.83  109.27
# 497  ORD0498 2023-02-19  North    LAPTOP  electronics   383.12   47.11
# 498  ORD0499 2023-03-01   East   MONITOR  electronics   968.34  265.05
# 499  ORD0500 2023-11-25  South     MOUSE  accessories   773.49  112.44
#
#      Quantity     Customer
# 0           1  Customer_95
# 1          10  Customer_30
# 2           9  Customer_29
# ...

# %%
df["Sales"].mean()
# Out:
# np.float64(1016.7684800000002)

# %%
df["Sales"].median()
# Out:
# 1016.7684800000001

# %%
df["Sales"].std()
# Out:
# 1.2973279272671295e-11

# %%
df["Profit"].min()
# Out:
# 6.12

# %%
df["Profit"].max()
# Out:
# 558.13

# %%
df["Region"].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15438/1873906486.py in <cell line: 0>()
# ----> 1 df["Region"].nunique()
#
# NameError: name 'df' is not defined

# %%
df["Region"].nunique()
# Out:
# 4

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    306
# Accessories    194
# Name: count, dtype: int64

# %%
df["Category"].value_counts(5)
# Out:
# Category
# Electronics    0.612
# Accessories    0.388
# Name: proportion, dtype: float64

# %%
df.groupby("Region")["Sales"].sum()
# Out:
# Region
# East     116410.20
# North    119270.78
# South    137860.13
# West     134843.13
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Salary"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_15438/2692597332.py in <cell line: 0>()
# ----> 1 df.groupby("Category")["Salary"].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Salary'

# %%
df["City"].value_counts()

# %%
df.groupby("Category")["Order_ID"].count()
# Out:
# Category
# Accessories    194
# Electronics    306
# Name: Order_ID, dtype: int64

# %%
df.groupby("Cateogory")["Revunue"].sum().sort_values(ascending=False).head(1)

# %%
df[df["Sales"] > df["Sales"].mean()]
# Out:
#     Order_ID  Order_Date Region   Product     Category    Sales  Profit  \
# 0    ORD0001  2023-11-24  South     Phone  Electronics  1496.02  166.39
# 3    ORD0004  2023-08-18   West   Monitor  Electronics  1529.67  137.54
# 4    ORD0005  2023-05-23  North    Tablet  Electronics  1916.57  257.11
# 5    ORD0006  2023-02-19   West  Keyboard  Accessories  1227.27  309.00
# 6    ORD0007  2023-03-05   East     Mouse  Accessories  1126.48  289.90
# ..       ...         ...    ...       ...          ...      ...     ...
# 482  ORD0483  2023-09-07   East  Keyboard  Accessories  1429.01  272.22
# 486  ORD0487  2023-06-13   East    Tablet  Electronics  1652.24  359.37
# 489  ORD0490  2023-09-10   West     Mouse  Accessories  1114.75   84.00
# 491  ORD0492  2023-01-11  South  Keyboard  Accessories  1905.74  130.64
# 492  ORD0493  2023-03-24   East     Phone  Electronics  1886.58  555.62
#
#      Quantity     Customer
# 0           1  Customer_95
# 3           1  Customer_44
# ...

# %%
df[df["Quantity"] >30]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Region, Product, Category, Sales, Profit, Quantity, Customer]
# Index: []

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Region, Product, Category, Sales, Profit, Quantity, Customer]
# Index: []

# %%
df[df["Region"]=="South"]
# Out:
#     Order_ID  Order_Date Region     Product     Category    Sales  Profit  \
# 0    ORD0001  2023-11-24  South       Phone  Electronics  1496.02  166.39
# 1    ORD0002  2023-02-22  South       Phone  Electronics   872.75   50.14
# 8    ORD0009  2023-02-21  South       Mouse  Accessories   934.15  241.50
# 11   ORD0012  2023-11-24  South     Printer  Electronics  1693.56  413.23
# 13   ORD0014  2023-12-02  South  Headphones  Accessories  1775.13  374.04
# ..       ...         ...    ...         ...          ...      ...     ...
# 484  ORD0485  2023-01-01  South       Mouse  Accessories   113.15   22.70
# 485  ORD0486  2023-10-17  South       Phone  Electronics   324.25   76.63
# 488  ORD0489  2023-01-01  South      Laptop  Electronics   904.53  140.12
# 491  ORD0492  2023-01-11  South    Keyboard  Accessories  1905.74  130.64
# 499  ORD0500  2023-11-25  South       Mouse  Accessories   773.49  112.44
#
#      Quantity     Customer
# 0           1  Customer_95
# ...

# %%
df[df["Order_Date"]=="2023"]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Region, Product, Category, Sales, Profit, Quantity, Customer]
# Index: []

# %%
q1=df["Sales"].quantile(0.25)
q3=df["Sales"].quantile(0.75)
IQR=q3-q1
df[(df["Sales"]<q1-1.5*IQR ) | (df["Sales"]>q3+1.5*IQR)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Region, Product, Category, Sales, Profit, Quantity, Customer]
# Index: []

# %%
df.corr(numeric_only=True)
# Out:
#              Sales    Profit  Quantity
# Sales     1.000000  0.789905 -0.007183
# Profit    0.789905  1.000000 -0.001056
# Quantity -0.007183 -0.001056  1.000000

# %%
df["Sales"].skew()
# Out:
# np.float64(-0.02222136901810002)

# %%
df["margin"]=df["Profit"]/df["Sales"]
df
# Out:
#     Order_ID  Order_Date Region   Product     Category    Sales  Profit  \
# 0    ORD0001  2023-11-24  South     Phone  Electronics  1496.02  166.39
# 1    ORD0002  2023-02-22  South     Phone  Electronics   872.75   50.14
# 2    ORD0003  2023-09-16   West    Laptop  Electronics   437.73   93.00
# 3    ORD0004  2023-08-18   West   Monitor  Electronics  1529.67  137.54
# 4    ORD0005  2023-05-23  North    Tablet  Electronics  1916.57  257.11
# ..       ...         ...    ...       ...          ...      ...     ...
# 495  ORD0496  2023-05-25   West   Monitor  Electronics   237.04   35.14
# 496  ORD0497  2023-01-28   West  Keyboard  Accessories   883.83  109.27
# 497  ORD0498  2023-02-19  North    Laptop  Electronics   383.12   47.11
# 498  ORD0499  2023-03-01   East   Monitor  Electronics   968.34  265.05
# 499  ORD0500  2023-11-25  South     Mouse  Accessories   773.49  112.44
#
#      Quantity     Customer    margin
# 0           1  Customer_95  0.111222
# ...

# %%
import seaborn as sns
sns.scatterplot(x='Sales', y='Profit', data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>
